# %%
from skimage.filters import threshold_local
import numpy as np
import argparse
import cv2
import imutils

# %%
def midpoint(ptA, ptB):
    return ((ptA[0] + ptB[0]) * 0.5, (ptA[1] + ptB[1]) * 0.5)

image1 = cv2.imread("/home/dheeraj/my_projects/my_project_env/practice/motion_detector/Detecting object size/feet.jpeg")
image = cv2.resize(image1, (200, 200))
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (7,7), 5)

edged = cv2.Canny(blur, 50, 100)
edged = cv2.dilate(edged, None, iterations=7)
edged = cv2.erode(edged, None, iterations=4)

cnts = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL,
    cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(cnts)

print(cnts)
cv2.imshow("blur", edged)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [array([[[ 39,   6]],
#
#        [[ 38,   7]],
#
#        [[ 37,   7]],
#
#        [[ 33,  11]],
#
#        [[ 32,  11]],
#
#        [[ 30,  13]],
#
#        [[ 29,  13]],
#
#        [[ 28,  14]],
#
#        [[ 27,  14]],
#
#        [[ 25,  16]],
#
#        [[ 24,  16]],
#
#        [[ 18,  22]],
#
#        [[ 17,  22]],
#
#        [[ 15,  24]],
#
#        [[ 14,  24]],
#
#        [[ 11,  27]],
#
#        [[ 10,  27]],
#
#        [[  6,  31]],
#
#        [[  5,  31]],
#
#        [[  4,  32]],
#
#        [[  0,  32]],
#
#        [[  0, 164]],
#
#        [[  4, 164]],
#
#        [[  5, 165]],
#
#        [[  5, 167]],
#
#        [[  7, 169]],
#
#        [[  7, 170]],
#
#        [[ 16, 179]],
#
#        [[ 17, 179]],
#
#        [[ 19, 181]],
#
#        [[ 21, 181]],
#
#        [[ 22, 182]],
#
#        [[ 24, 182]],
#
#        [[ 25, 183]],
#
#        [[ 27, 183]],
#
#        [[ 28, 184]],
#
#        [[ 31, 184]],
#
#        [[ 32, 185]],
#
#        [[ 66, 185]],
#
#        [[ 67, 184]],
#
#        [[ 74, 184]],
#
#        [[ 75, 183]],
#
#        [[ 81, 183]],
#
#        [[ 82, 182]],
#
#        [[ 88, 182]],
#
#        [[ 89, 181]],
#
#        [[126, 181]],
#
#        [[127, 182]],
#
#        [[130, 182]],
#
#        [[131, 183]],
#
#        [[134, 183]],
#
#        [[135, 184]],
#
#        [[152, 184]],
#
#        [[153, 183]],
#
#        [[155, 183]],
#
#        [[156, 182]],
#
#        [[178, 182]],
#
#        [[179, 181]],
#
#        [[181, 181]],
#
#        [[182, 180]],
#
#        [[183, 180]],
#
#        [[184, 179]],
#
#        [[186, 179]],
#
#        [[187, 178]],
#
#        [[187, 177]],
#
#        [[188, 176]],
#
#        [[189, 176]],
#
#        [[191, 174]],
#
#        [[191, 173]],
#
#        [[192, 172]],
#
#        [[192, 170]],
#
#        [[194, 168]],
#
#        [[194, 167]],
#
#        [[195, 166]],
#
#        [[199, 166]],
#
#        [[199, 143]],
#
#        [[195, 143]],
#
#        [[194, 142]],
#
#        [[194, 141]],
#
#        [[190, 137]],
#
#        [[189, 137]],
#
#        [[188, 136]],
#
#        [[188, 135]],
#
#        [[186, 135]],
#
#        [[184, 133]],
#
#        [[184, 132]],
#
#        [[182, 130]],
#
#        [[181, 130]],
#
#        [[179, 128]],
#
#        [[178, 128]],
#
#        [[177, 127]],
#
#        [[176, 127]],
#
#        [[175, 126]],
#
#        [[175, 123]],
#
#        [[174, 123]],
#
#        [[171, 120]],
#
#        [[160, 120]],
#
#        [[159, 119]],
#
#        [[159, 117]],
#
#        [[155, 117]],
#
#        [[154, 116]],
#
#        [[154, 114]],
#
#        [[152, 112]],
#
#        [[151, 112]],
#
#        [[149, 110]],
#
#        [[148, 110]],
#
#        [[147, 109]],
#
#        [[146, 109]],
#
#        [[144, 107]],
#
#        [[144, 106]],
#
#        [[143, 106]],
#
#        [[142, 105]],
#
#        [[140, 105]],
#
#        [[139, 104]],
#
#        [[127, 104]],
#
#        [[126, 105]],
#
#        [[116, 105]],
#
#        [[115, 104]],
#
#        [[114, 104]],
#
#        [[113, 103]],
#
#        [[112, 103]],
#
#        [[111, 102]],
#
#        [[110, 102]],
#
#        [[109, 101]],
#
#        [[108, 101]],
#
#        [[107, 100]],
#
#        [[106, 100]],
#
#        [[105,  99]],
#
#        [[104,  99]],
#
#        [[102,  97]],
#
#        [[101,  97]],
#
#        [[100,  96]],
#
#        [[ 99,  96]],
#
#        [[ 98,  95]],
#
#        [[ 97,  95]],
#
#        [[ 96,  94]],
#
#        [[ 95,  94]],
#
#        [[ 94,  93]],
#
#        [[ 93,  93]],
#
#        [[ 92,  92]],
#
#        [[ 91,  92]],
#
#        [[ 89,  90]],
#
#        [[ 88,  90]],
#
#        [[ 87,  89]],
#
#        [[ 86,  89]],
#
#        [[ 84,  87]],
#
#        [[ 83,  87]],
#
#        [[ 81,  85]],
#
#        [[ 80,  85]],
#
#        [[ 78,  83]],
#
#        [[ 78,  82]],
#
#        [[ 77,  81]],
#
#        [[ 77,  80]],
#
#        [[ 75,  78]],
#
#        [[ 75,  77]],
#
#        [[ 74,  76]],
#
#        [[ 74,  75]],
#
#        [[ 73,  74]],
#
#        [[ 73,  72]],
#
#        [[ 72,  71]],
#
#        [[ 72,  70]],
#
#        [[ 71,  69]],
#
#        [[ 71,  67]],
#
#        [[ 70,  66]],
#
#        [[ 70,  64]],
#
#        [[ 69,  63]],
#
#        [[ 69,  60]],
#
#        [[ 68,  59]],
#
#        [[ 68,  57]],
#
#        [[ 67,  56]],
#
#        [[ 67,  54]],
#
#        [[ 66,  53]],
#
#        [[ 66,  51]],
#
#        [[ 65,  50]],
#
#        [[ 65,  47]],
#
#        [[ 64,  46]],
#
#        [[ 64,  44]],
#
#        [[ 63,  43]],
#
#        [[ 63,  41]],
#
#        [[ 62,  40]],
#
#        [[ 62,  37]],
#
#        [[ 61,  36]],
#
#        [[ 61,  34]],
#
#        [[ 60,  33]],
#
#        [[ 60,  30]],
#
#        [[ 59,  29]],
#
#        [[ 59,  26]],
#
#        [[ 58,  25]],
#
#        [[ 58,  22]],
#
#        [[ 57,  21]],
#
#        [[ 57,  19]],
#
#        [[ 56,  18]],
#
#        [[ 56,  15]],
#
#        [[ 55,  14]],
#
#        [[ 55,  11]],
#
#        [[ 54,  10]],
#
#        [[ 54,   8]],
#
#        [[ 46,   8]],
#
#        [[ 45,   7]],
#
#        [[ 45,   6]]], dtype=int32)]
